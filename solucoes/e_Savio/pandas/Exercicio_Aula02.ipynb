# %%
import pandas as pd
import numpy as np
df = pd.read_table('https://raw.githubusercontent.com/advinstai/python-datascience/master/csv/Auto.csv', sep=',')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
count_nulls = df.isnull().sum(axis = 0)
print(count_nulls)
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
df_not = df[df['horsepower'] == '?']
df_not.head()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0          ?    2046          19.0    71
# 126  21.0          6         200.0          ?    2875          17.0    74
# 330  40.9          4          85.0          ?    1835          17.3    80
# 336  23.6          4         140.0          ?    2905          14.3    80
# 354  34.5          4         100.0          ?    2320          15.8    81
#
#      origin                  name
# 32        1            ford pinto
# 126       1         ford maverick
# 330       2  renault lecar deluxe
# 336       1    ford mustang cobra
# 354       2           renault 18i

# %%
df_not = df[df['horsepower'] != '?']
df_not.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df_count = df['horsepower'][df['horsepower'] == '?'].count()
print(df_count)
# Out:
# 5

# %%
df_zero = df[df['horsepower'] == '?'] = 0
df[df['horsepower'] == '?']
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []

# %%
df.replace('?', 0)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
df['horsepower']
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
#       ...
# 392     86
# 393     52
# 394     84
# 395     79
# 396     82
# Name: horsepower, Length: 397, dtype: object

# %%
df_mean = df.mean()
print(df_mean)
# Out:
# mpg               23.150630
# cylinders          5.403023
# displacement     191.963476
# weight          2940.083123
# acceleration      15.345592
# year              75.022670
# origin             1.556675
# dtype: float64

# %%
lista_de_colunas = df.columns

# %%
lista_de_colunas
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')
