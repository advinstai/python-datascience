# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1 Leia os dados train.csv usando pandas

# %%
# !ls
# Out:
# carros.csv     Exercicio_Aula02.ipynb	Pandas_aula_01.ipynb
# Cilindors.csv  Exercicios_carros.ipynb	titanic.md
# df_titan.csv   Exercicio_Titanic.ipynb	train.csv

# %%
df = pd.read_csv('train.csv', header=0)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### 2 Remova a coluna com nomes de pessoas

# %%
df2 = df.drop(columns='Name')
df2.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# ### 3 A coluna Cabin contém uma letra e um número. Crie uma nova coluna chamada deck usando apenas a letra de cada registro presente na coluna Cabin.

# %%
df2['deck'] = df2['Cabin'].astype(str).str[0]
df2.head(3)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
#
#              Ticket     Fare Cabin Embarked deck
# 0         A/5 21171   7.2500   NaN        S    n
# 1          PC 17599  71.2833   C85        C    C
# 2  STON/O2. 3101282   7.9250   NaN        S    n

# %% [markdown]
# ### 4 Substitua os valores ausentes pela média de valores da coluna

# %%
df2.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df2[['Survived', 'Age', 'Fare']].mean()
# Out:
# Survived     0.383838
# Age         29.699118
# Fare        32.204208
# dtype: float64

# %%
df3 = df2.fillna(df2.mean())
df3.head(5)
#Entretanto a valores que nao deveriam ser passados como media
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked deck
# 0         A/5 21171   7.2500   NaN        S    n
# 1          PC 17599  71.2833   C85        C    C
# 2  STON/O2. 3101282   7.9250   NaN        S    n
# 3            113803  53.1000  C123        S    C
# 4            373450   8.0500   NaN        S    n

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'deck'],
#       dtype='object')

# %%
df3_r = df2[['Survived', 'Age', 'Fare']].fillna(df2[['Survived', 'Age', 'Fare']].mean())
df3_r.head(3)
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250

# %% [markdown]
# ### 5 Os valores da coluna "embarked" sao os seguintes: C = Cherbourg, Q = Queenstown, S = Southampton
#
# ### 6 Crie um CSV com essas uma coluna nome_cidade_de_embarque: C = Cherbourg, Q = Queenstown, S = Southampton e mais uma coluna chamada população com valores hipotéticos, faça um merge entre o CSV train.csv e esse novo CSV com os nomes das cidades. Implemente um filtro de passageiros por população da cidade de embarque

# %%
dCSV = pd.DataFrame(df2['Embarked'])

# %%
dCSV.head()
# Out:
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
# df_teste = pd.DataFrame(df2)
# m = df2.Embarked == 'S'
# df_teste['Embarked'] = df2.where(~m,other='Southampton')
# df_teste.head()

# %%
dCSV.loc[(dCSV.Embarked == 'S'),'cidade_de_embarque']='Southampton'
dCSV.loc[(dCSV.Embarked == 'C'),'cidade_de_embarque']='Cherbourg'
dCSV.loc[(dCSV.Embarked == 'Q'),'cidade_de_embarque']='Queenstown'
dCSV.head()
#df2['cidade_de_embarque'] = dCSV['Embarked']
#df2.head()
# Out:
#   Embarked cidade_de_embarque
# 0        S        Southampton
# 1        C          Cherbourg
# 2        S        Southampton
# 3        S        Southampton
# 4        S        Southampton

# %%
dCSV.loc[(dCSV.cidade_de_embarque == 'Southampton'), 'População com valores hipotéticos'] = np.random.randint(1000, 10000)
dCSV.loc[(dCSV.cidade_de_embarque == 'Cherbourg'), 'População com valores hipotéticos'] = np.random.randint(1000, 10000)
dCSV.loc[(dCSV.cidade_de_embarque == 'Queenstown'), 'População com valores hipotéticos'] = np.random.randint(1000, 10000)

# %%
dCSV.head()
# Out:
#   Embarked cidade_de_embarque  População com valores hipotéticos
# 0        S        Southampton                             5542.0
# 1        C          Cherbourg                             9508.0
# 2        S        Southampton                             5542.0
# 3        S        Southampton                             5542.0
# 4        S        Southampton                             5542.0

# %%
dCSV.to_csv('df_titan.csv')

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked deck
# 0         A/5 21171   7.2500   NaN        S    n
# 1          PC 17599  71.2833   C85        C    C
# 2  STON/O2. 3101282   7.9250   NaN        S    n
# 3            113803  53.1000  C123        S    C
# 4            373450   8.0500   NaN        S    n

# %%
df_final = df2.merge(dCSV, how='inner', left_on='Embarked', right_on='Embarked')

# %%
df_final.head(10)
# Out:
#    PassengerId  Survived  Pclass   Sex   Age  SibSp  Parch     Ticket  Fare  \
# 0            1         0       3  male  22.0      1      0  A/5 21171  7.25
# 1            1         0       3  male  22.0      1      0  A/5 21171  7.25
# 2            1         0       3  male  22.0      1      0  A/5 21171  7.25
# 3            1         0       3  male  22.0      1      0  A/5 21171  7.25
# 4            1         0       3  male  22.0      1      0  A/5 21171  7.25
# 5            1         0       3  male  22.0      1      0  A/5 21171  7.25
# 6            1         0       3  male  22.0      1      0  A/5 21171  7.25
# 7            1         0       3  male  22.0      1      0  A/5 21171  7.25
# 8            1         0       3  male  22.0      1      0  A/5 21171  7.25
# 9            1         0       3  male  22.0      1      0  A/5 21171  7.25
#
#   Cabin Embarked deck cidade_de_embarque  População com valores hipotéticos
# 0   NaN        S    n        Southampton                             5542.0
# 1   NaN        S    n        Southampton                             5542.0
# 2   NaN        S    n        Southampton                             5542.0
# 3   NaN        S    n        Southampton                             5542.0
# 4   NaN        S    n        Southampton                             5542.0
# 5   NaN        S    n        Southampton                             5542.0
# 6   NaN        S    n        Southampton                             5542.0
# 7   NaN        S    n        Southampton                             5542.0
# 8   NaN        S    n        Southampton                             5542.0
# 9   NaN        S    n        Southampton                             5542.0

# %%
df_consolidado = df_final.drop_duplicates()

# %%
def filtro_pop(df, num):
    dframe = df[df['População com valores hipotéticos'] >= num]
    return dframe
    
filtro_pop(df_consolidado, 9000 )
# Out:
#         PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 414736            2         1       1  female  38.0      1      0
# 414904           10         1       2  female  14.0      1      0
# 415072           20         1       3  female   NaN      0      0
# 415240           27         0       3    male   NaN      0      0
# 415408           31         0       1    male  40.0      0      0
# ...             ...       ...     ...     ...   ...    ...    ...
# 442120          867         1       2  female  27.0      1      0
# 442288          875         1       2  female  28.0      1      0
# 442456          876         1       3  female  15.0      0      0
# 442624          880         1       1  female  56.0      0      1
# 442792          890         1       1    male  26.0      0      0
#
#                Ticket     Fare Cabin Embarked deck cidade_de_embarque  \
# 414736       PC 17599  71.2833   C85        C    C          Cherbourg
# 414904         237736  30.0708   NaN        C    n          Cherbourg
# 415072           2649   7.2250   NaN        C    n          Cherbourg
# 415240           2631   7.2250   NaN        C    n          Cherbourg
# 415408       PC 17601  27.7208   NaN        C    n          Cherbourg
# ...               ...      ...   ...      ...  ...                ...
# 442120  SC/PARIS 2149  13.8583   NaN        C    n          Cherbourg
# 442288      P/PP 3381  24.0000   NaN        C    n          Cherbourg
# 442456           2667   7.2250   NaN        C    n          Cherbourg
# 442624          11767  83.1583   C50        C    C          Cherbourg
# 442792         111369  30.0000  C148        C    C          Cherbourg
#
#         População com valores hipotéticos
# 414736                             9508.0
# 414904                             9508.0
# 415072                             9508.0
# 415240                             9508.0
# 415408                             9508.0
# ...                                   ...
# 442120                             9508.0
# 442288                             9508.0
# 442456                             9508.0
# 442624                             9508.0
# 442792                             9508.0
#
# [168 rows x 14 columns]
