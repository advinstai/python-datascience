# %% [markdown]
# # Lista SQL
#
# 1. Leia os dados train.csv usando pandas

# %%
import sqlite3
import pandas as pd

dfTitanic = pd.read_csv('https://raw.githubusercontent.com/advinstai/python-datascience/master/Exercicios/titanic/train.csv',",")

display(dfTitanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 2. Remova a coluna com nomes de pessoas

# %%
dfTitanic = dfTitanic.drop('Name',axis=1)
display(dfTitanic)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# 3. A coluna Cabin contém uma letra e um número. Crie uma nova coluna chamada deck usando apenas a letra de cada registro presente na coluna Cabin.

# %%
dfTitanic['deck'] = dfTitanic['Cabin'].astype(str).str[0]
display(dfTitanic)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked deck
# 0           A/5 21171   7.2500   NaN        S    n
# 1            PC 17599  71.2833   C85        C    C
# 2    STON/O2. 3101282   7.9250   NaN        S    n
# ...

# %% [markdown]
# 4. Substitua os valores ausentes pela média de valores da coluna

# %%
dfTitanic = dfTitanic.fillna(dfTitanic.mean())
display(dfTitanic)
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch  \
# 0              1         0       3    male  22.000000      1      0
# 1              2         1       1  female  38.000000      1      0
# 2              3         1       3  female  26.000000      0      0
# 3              4         1       1  female  35.000000      1      0
# 4              5         0       3    male  35.000000      0      0
# ..           ...       ...     ...     ...        ...    ...    ...
# 886          887         0       2    male  27.000000      0      0
# 887          888         1       1  female  19.000000      0      0
# 888          889         0       3  female  29.699118      1      2
# 889          890         1       1    male  26.000000      0      0
# 890          891         0       3    male  32.000000      0      0
#
#                Ticket     Fare Cabin Embarked deck
# 0           A/5 21171   7.2500   NaN        S    n
# ...

# %% [markdown]
# 5 Os valores da coluna "embarked" sao os seguintes: C = Cherbourg, Q = Queenstown, S = Southampton
#
# 6 Crie um CSV com essas uma coluna nome_cidade_de_embarque: C = Cherbourg, Q = Queenstown, S = Southampton e mais uma coluna chamada população com valores hipotéticos, faça um merge entre o CSV train.csv e esse novo CSV com os nomes das cidades. Implemente um filtro de passageiros por população da cidade de embarque

# %%
import numpy as np
x = {'C':"Cherbourg", 'Q':"Queenstown", 'S':"Southampton"}
y = {'C':150030, 'Q':270130, 'S':305200}
dfTitanic['nome_cidade_de_embarque'] = dfTitanic['Embarked']
dfTitanic['populacao'] = dfTitanic['Embarked']
dfTitanic = dfTitanic.replace({"nome_cidade_de_embarque": x})
dfTitanic = dfTitanic.replace({"populacao": y})
dfTitanic.to_csv('Titanic.csv')

dfTrain = pd.read_csv('https://raw.githubusercontent.com/advinstai/python-datascience/master/Exercicios/titanic/train.csv')
dfMerge = pd.merge(dfTrain, dfTitanic)

dfFilter = dfMerge[(dfMerge['populacao']==150030)]
display(dfFilter)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 8             10         1       2
# 24            31         0       1
# 26            35         0       1
# 30            40         1       3
# ..           ...       ...     ...
# 692          867         1       2
# 699          875         1       2
# 700          876         1       3
# 703          880         1       1
# 712          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 8                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 24                            Uruchurtu, Don. Manuel E    male  40.0      0
# 26                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 30                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...
