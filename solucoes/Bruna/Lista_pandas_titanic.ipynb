# %% [markdown]
# ## Lista Pandas / SQL : Titanic

# %% [markdown]
# * Leia os dados train.csv usando pandas

# %%
import pandas as pd

#abrindo o arquivo por html
url='https://raw.githubusercontent.com/advinstai/python-datascience/master/Exercicios/titanic/train.csv'
from_url = pd.read_table(url, sep=',')  #le a tabela e separa por virgula

from_url
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# * Remova a coluna com nomes de pessoas

# %%
from_url.drop(columns=['Name'])
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# * A coluna Cabin contém uma letra e um número. Crie uma nova coluna chamada deck usando apenas a letra de cada registro presente na coluna Cabin.

# %%
#Criando um novo dataframe a partir de from_url
new_data = from_url

#criando uma nova coluna espelhada a partir da coluna Cabin
new_data["deck"] = from_url["Cabin"]

#aplicando ao dataframe, coluna deck, dados string tal que tudo o que nao for letra(replace("\d+","")) recebe vazio
new_data.deck.str.replace("\d+","").dropna()
# Out:
# 1          C
# 3          C
# 6          E
# 10         G
# 11         C
#        ...
# 871        D
# 872    B B B
# 879        C
# 887        B
# 889        C
# Name: deck, Length: 204, dtype: object

# %% [markdown]
# * Substitua os valores ausentes pela média de valores da coluna

# %%
new_data = new_data.fillna(new_data.mean())
new_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  deck
# 0      0         A/5 21171   7.2500   NaN        S   NaN
# 1      0          PC 17599  71.2833   C85        C   C85
# 2      0  STON/O2. 3101282   7.9250   NaN        S   NaN
# 3      0            113803  53.1000  C123        S  C123
# ...

# %% [markdown]
# * Os valores da coluna "embarked" sao os seguintes: C = Cherbourg, Q = Queenstown, S = Southampton.  Crie um CSV com essas uma coluna nome_cidade_de_embarque: C = Cherbourg, Q = Queenstown, S = Southampton e mais uma coluna chamada população com valores hipotéticos, faça um merge entre o CSV train.csv e esse novo CSV com os nomes das cidades. Implemente um filtro de passageiros por população da cidade de embarque

# %%
#dicionario
dados_csv = {'city': 'C', 'population': 10000 }, {'city': 'Q', 'population': 50000 }, {'city': 'S', 'population': 70000 }

#transformando o filtro em DataFrame
dfcsv = pd.DataFrame(data = dados_csv)

#Realizando o merge entre os dois DataFrame
df_final = pd.merge(from_url, dfcsv, left_on = 'Embarked' , right_on = 'city', how = 'inner')

#filtro

l = df_final.loc[(df_final["population"] > 50000)]

l
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              3         1       3
# 2              4         1       1
# 3              5         0       3
# 4              7         0       1
# ..           ...       ...     ...
# 639          884         0       2
# 640          885         0       3
# 641          887         0       2
# 642          888         1       1
# 643          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 1                          Heikkinen, Miss. Laina  female  26.0      0      0
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 3                        Allen, Mr. William Henry    male  35.0      0      0
# 4                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...
