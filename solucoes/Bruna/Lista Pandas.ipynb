# %% [markdown]
# # Lista 2 de exercicios Pandas

# %% [markdown]
# * Do arquivo carros, imprima as primeiras e as últimas cinco linhas. Faça uma versão que abre o arquivo a partir do csv e outra que abre a partir da url.

# %%
import pandas as pd
import numpy as np

#abrindo o arquivo por html
url='https://raw.githubusercontent.com/advinstai/python-datascience/master/Exercicios/carros.csv'
#from_url = pd.read_table(url, sep=',')  #le a tabela e separa por virgula

#abre um csv
from_csv = pd.read_csv('carros.csv', delimiter = ',')  #le a tabela e separa por virgula

#printar as cinco primeiras linhas
from_csv.head()

#outra opcao
#from_csv[:5]

#printar as cinco ultimas linhas
from_csv.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# * Encontre o nome da empresa de carros mais cara

# %%
maior_valor = from_csv["price"].max()
from_csv[from_csv.price == maior_valor]

# %% [markdown]
# * Mostre a média de preços

# %%
from_csv.price.mean()
#outra opcao

from_csv.price.describe()
# Out:
# count       58.000000
# mean     15387.000000
# std      11320.259841
# min       5151.000000
# 25%       6808.500000
# 50%      11095.000000
# 75%      18120.500000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# * Mostre o valor mais alto e mais baixo de horsepower

# %%
maximo = from_csv["horsepower"].max()
minimo = from_csv["horsepower"].min()

print("valor maximo:", maximo,"valor minimo:", minimo)

# %% [markdown]
# * Mostre a informação de todos os carros da marcar toyota

# %%
#from_csv.company == 'toyota' retorna true ou false

from_csv[from_csv.company == 'toyota']

# %% [markdown]
# * Faça uma função que filtra os carros por cilindro e salva em outro arquivo CSV

# %%
#cylinders = from_csv["num-of-cylinders"]

cylinders = from_csv.loc[from_csv["num-of-cylinders"].isin(["five","four"])]

cylinders
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible        88.6   168.8        dohc
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 3       3           audi        sedan        99.8   176.6         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 8      10            bmw        sedan       101.2   176.8         ohc
# 14     17      chevrolet    hatchback        94.5   155.9         ohc
# 15     18      chevrolet        sedan        94.5   158.8         ohc
# 16     19          dodge    hatchback        93.7   157.3         ohc
# 17     20          dodge    hatchback        93.7   157.3         ohc
# ...
